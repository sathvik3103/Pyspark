# %% [markdown]
# <a href="https://colab.research.google.com/github/sathvik3103/Pyspark/blob/main/Basics_of_Pyspark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Apache Spark is a unified analytics engine for large-scale data processing. It provides high-level APIs in Java, Scala, Python and R, and an optimized engine that supports general execution graphs. It also supports a rich set of higher-level tools including Spark SQL for SQL and structured data processing, pandas API on Spark for pandas workloads, MLlib for machine learning, GraphX for graph processing, and Structured Streaming for incremental computation and stream processing.Apache spark helps to run our workload faster (100x).

# %% [markdown]
# PySpark is the Python API for Apache Spark. It enables you to perform real-time, large-scale data processing in a distributed environment using Python. PySpark supports all of Spark’s features such as Spark SQL, DataFrames, Structured Streaming, Machine Learning (MLlib) and Spark Core.

# %% [markdown]
# 1. https://spark.apache.org/docs/latest/
# 2. https://spark.apache.org/docs/latest/api/python/index.html

# %%
! pip install pyspark

# %%
import pyspark as pk

# %%
import pandas as pd
pd.read_csv('Tailwind Traders Sales.csv')
# Out:
#      OrderID      Customer Name                Product Name  \
# 0        1024     Jane Smith               UltraGrip Hammer
# 1        1025     Darren White            Luminous Bulb 60W
# 2        1026     Lucy Roberts                Oakwood Shelf
# 3        1027     Mark Lewis                 ProTile Cutter
# 4        1028     Olivia Graham            Garden Glove Set
# 5        1029     Jack Thompson         Steel Nails (1inch)
# 6        1030     Mia Hughes            Luxury Paint (Blue)
# 7        1031     Aaron Walker         Kitchen Sink (Steel)
# 8        1032     Lily Peterson             Power Drill Set
# 9        1033     Ben Foster               Floral Wallpaper
# 10       1034     Owen Gray                 Brass Door Knob
# 11       1035     Amelia Carter           LED Garden Lights
# 12       1036     Liam Clark                    Compost Bin
# 13       1037     Sophia Turner          Ceramic Vase (Red)
# 14       1038     Jacob Moore               Patio Chair Set
# ...

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Practice').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://dacebdee9153:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark=spark.read.csv('Tailwind Traders Sales.csv')

# %%
import pandas as pd
df=pd.read_csv('Tailwind Traders Sales.csv')

# %%
df_pyspark.show()
# Out:
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+-------------------+---------+----------+------------------+---------------+
# |      _c0|              _c1|                 _c2|                 _c3|                _c4|            _c5|               _c6|_c7|  _c8|   _c9|            _c10|        _c11|    _c12|    _c13|    _c14|   _c15|    _c16|       _c17|       _c18|       _c19|               _c20|     _c21|      _c22|              _c23|           _c24|
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+-------------------+---------+----------+------------------+---------------+
# ...

# %%
df_pyspark=spark.read.option('header','true').csv('Tailwind Traders Sales.csv')

# %%
df_pyspark.show()
# Out:
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Gross Product Price|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# ...

# %%
df.head()
# Out:
#     OrderID    Customer Name          Product Name  \
# 0       1024   Jane Smith         UltraGrip Hammer
# 1       1025   Darren White      Luminous Bulb 60W
# 2       1026   Lucy Roberts          Oakwood Shelf
# 3       1027   Mark Lewis           ProTile Cutter
# 4       1028   Olivia Graham      Garden Glove Set
#
#                                  Product Description  Gross Product Price  \
# 0  A sturdy hammer with an ergonomic grip for car...                   60
# 1  Energy-saving 60W bulb with a bright luminous ...                   35
# 2   A durable oakwood shelf for home and office use.                  250
# 3   High precision tile cutter for professional use.                   15
# 4            Comfortable gloves for gardening tasks.                   55
#
#    Tax Per Product  Quantity Purchased   GR     TT      NR  ...  Rating  \
# 0             8.40                   2  120  16.80  103.20  ...     4.5
# ...

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# sql.dataframe, just like pandas dataframe

# %%
df_pyspark.head() #different output (list format) than the output (dataframe format) for  .head() in pandas because it is sql dataframe in spark
# Out:
# Row( OrderID ='1024',  Customer Name   =' Jane Smith      ', Product Name='UltraGrip Hammer', Product Description='A sturdy hammer with an ergonomic grip for carpentry works.', Gross Product Price='60', Tax Per Product='8.4', Quantity Purchased='2', GR='120', TT='16.8', NR='103.2', Product Category='Tools',  SKU Number =' TWH-024    ',  Weight =' 0,1  ',  Color  =' Red    ',  Size  =' Small  ',  Rating=' 4.5   ',  Stock  ='320',  Country ID='1',  Sales Rep =' Alice     ',  CustomerID=' C024     ',  Address        =' 121 Blvd        ',  Zip Code='46575',  Phone    ='1112222',  Email            =' jsmith@mail.com  ',  Loyalty Points='7')

# %%
df_pyspark.printSchema() #just like df.info() in pandas
# Out:
# root
#  |--  OrderID : string (nullable = true)
#  |--  Customer Name   : string (nullable = true)
#  |-- Product Name: string (nullable = true)
#  |-- Product Description: string (nullable = true)
#  |-- Gross Product Price: string (nullable = true)
#  |-- Tax Per Product: string (nullable = true)
#  |-- Quantity Purchased: string (nullable = true)
#  |-- GR: string (nullable = true)
#  |-- TT: string (nullable = true)
#  |-- NR: string (nullable = true)
#  |-- Product Category: string (nullable = true)
#  |--  SKU Number : string (nullable = true)
#  |--  Weight : string (nullable = true)
#  |--  Color  : string (nullable = true)
#  |--  Size  : string (nullable = true)
#  |--  Rating: string (nullable = true)
#  |--  Stock  : string (nullable = true)
#  |--  Country ID: string (nullable = true)
#  |--  Sales Rep : string (nullable = true)
#  |--  CustomerID: string (nullable = true)
#  |--  Address        : string (nullable = true)
#  |--  Zip Code: string (nullable = true)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0    OrderID             54 non-null     int64
#  1    Customer Name       54 non-null     object
#  2   Product Name         54 non-null     object
#  3   Product Description  54 non-null     object
#  4   Gross Product Price  54 non-null     int64
#  5   Tax Per Product      54 non-null     float64
#  6   Quantity Purchased   54 non-null     int64
#  7   GR                   54 non-null     int64
#  8   TT                   54 non-null     float64
#  9   NR                   54 non-null     float64
#  10  Product Category     54 non-null     object
#  11   SKU Number          54 non-null     object
#  12   Weight              54 non-null     object
#  13   Color               54 non-null     object
#  14   Size                54 non-null     object
# ...

# %% [markdown]
# -----------

# %%
df_pyspark=spark.read.option('header','true').csv('Tailwind Traders Sales.csv',inferSchema=True) #if inferschema is false it will by default consider all feature values as string. (as seen above)

# %%
df_pyspark.printSchema()
# Out:
# root
#  |--  OrderID : integer (nullable = true)
#  |--  Customer Name   : string (nullable = true)
#  |-- Product Name: string (nullable = true)
#  |-- Product Description: string (nullable = true)
#  |-- Gross Product Price: integer (nullable = true)
#  |-- Tax Per Product: double (nullable = true)
#  |-- Quantity Purchased: integer (nullable = true)
#  |-- GR: integer (nullable = true)
#  |-- TT: double (nullable = true)
#  |-- NR: double (nullable = true)
#  |-- Product Category: string (nullable = true)
#  |--  SKU Number : string (nullable = true)
#  |--  Weight : string (nullable = true)
#  |--  Color  : string (nullable = true)
#  |--  Size  : string (nullable = true)
#  |--  Rating: double (nullable = true)
#  |--  Stock  : integer (nullable = true)
#  |--  Country ID: integer (nullable = true)
#  |--  Sales Rep : string (nullable = true)
#  |--  CustomerID: string (nullable = true)
#  |--  Address        : string (nullable = true)
#  |--  Zip Code: string (nullable = true)
# ...

# %%
df_pyspark=spark.read.csv('Tailwind Traders Sales.csv',header=True,inferSchema=True) #just another way of writing header and inferSchema true
df_pyspark.show()
# Out:
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Gross Product Price|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# ...

# %%
type(df_pyspark.head())
# Out:
# pyspark.sql.types.Row

# %%
df_pyspark.select(' Customer Name   ','Gross Product Price')
# Out:
# DataFrame[ Customer Name   : string, Gross Product Price: int]

# %%
df_pyspark.select(' Customer Name   ','Gross Product Price').show()
# Out:
# +-----------------+-------------------+
# | Customer Name   |Gross Product Price|
# +-----------------+-------------------+
# | Jane Smith      |                 60|
# | Darren White    |                 35|
# | Lucy Roberts    |                250|
# | Mark Lewis      |                 15|
# | Olivia Graham   |                 55|
# | Jack Thompson   |                 75|
# | Mia Hughes      |                 50|
# | Aaron Walker    |                 90|
# | Lily Peterson   |                180|
# | Ben Foster      |                  3|
# | Owen Gray       |                300|
# | Amelia Carter   |                 50|
# | Liam Clark      |                 60|
# | Sophia Turner   |                 40|
# | Jacob Moore     |                 45|
# | Ava Lee         |                 80|
# | Ethan Wilson    |                200|
# | Charlotte Adams |                 65|
# | Lucas Taylor    |                110|
# | Mia Roberts     |                 95|
# ...

# %%
df_pyspark[' Customer Name   ']
# Out:
# Column<' Customer Name   '>

# %%
df_pyspark[' Customer Name   '].show() #doesn't work. because, 'Column' object is not callable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-f234512674d7> in <cell line: 1>()
# ----> 1 df_pyspark[' Customer Name   '].show() #doesn't work. because, 'Column' object is not callable
#
# TypeError: 'Column' object is not callable

# %%
df_pyspark.dtypes
# Out:
# [(' OrderID ', 'int'),
#  (' Customer Name   ', 'string'),
#  ('Product Name', 'string'),
#  ('Product Description', 'string'),
#  ('Gross Product Price', 'int'),
#  ('Tax Per Product', 'double'),
#  ('Quantity Purchased', 'int'),
#  ('GR', 'int'),
#  ('TT', 'double'),
#  ('NR', 'double'),
#  ('Product Category', 'string'),
#  (' SKU Number ', 'string'),
#  (' Weight ', 'string'),
#  (' Color  ', 'string'),
#  (' Size  ', 'string'),
#  (' Rating', 'double'),
#  (' Stock  ', 'int'),
#  (' Country ID', 'int'),
#  (' Sales Rep ', 'string'),
#  (' CustomerID', 'string'),
#  (' Address        ', 'string'),
#  (' Zip Code', 'string'),
#  (' Phone    ', 'int'),
#  (' Email            ', 'string'),
#  (' Loyalty Points', 'int')]

# %%
df_pyspark.describe()
# Out:
# DataFrame[summary: string,  OrderID : string,  Customer Name   : string, Product Name: string, Product Description: string, Gross Product Price: string, Tax Per Product: string, Quantity Purchased: string, GR: string, TT: string, NR: string, Product Category: string,  SKU Number : string,  Weight : string,  Color  : string,  Size  : string,  Rating: string,  Stock  : string,  Country ID: string,  Sales Rep : string,  CustomerID: string,  Address        : string,  Zip Code: string,  Phone    : string,  Email            : string,  Loyalty Points: string]

# %%
df_pyspark.describe().show()
# Out:
# +-------+-----------------+-----------------+--------------------+--------------------+-------------------+------------------+------------------+------------------+-----------------+-----------------+----------------+------------+-----------------+--------+--------+------------------+-----------------+------------------+-----------+-----------+-----------------+-----------------+-------------------+--------------------+------------------+
# |summary|         OrderID | Customer Name   |        Product Name| Product Description|Gross Product Price|   Tax Per Product|Quantity Purchased|                GR|               TT|               NR|Product Category| SKU Number |          Weight | Color  |  Size  |            Rating|          Stock  |        Country ID| Sales Rep | CustomerID|  Address        |         Zip Code|          Phone    |   Email            |    Loyalty Points|
# ...

# %%
df_pyspark=df_pyspark.withColumn('Gross Product Price After 20% Discount',df_pyspark['Gross Product Price']*0.8)

# %%
df_pyspark.show()
# Out:
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+--------------------------------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Gross Product Price|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|Gross Product Price After 20% Discount|
# ...

# %%
df_pyspark=df_pyspark.drop('Gross Product Price After 20% Discount')

# %%
df_pyspark.show()
# Out:
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Gross Product Price|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# ...

# %%
df_pyspark.withColumnRenamed('Gross Product Price','New Gross Product Price').show()
# Out:
# +---------+-----------------+--------------------+--------------------+-----------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|New Gross Product Price|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|
# ...

# %%
df_pyspark.show()
# Out:
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Gross Product Price|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# ...

# %% [markdown]
# not an inpalce function/operation. so need to assign a variable just like withcolumn and withColumnRenamed

# %%
df_pyspark = df_pyspark.withColumnRenamed('Gross Product Price','New Gross Product Price')

# %% [markdown]
# --------

# %%
df_pyspark.show()
# Out:
# +---------+-----------------+--------------------+--------------------+-----------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|New Gross Product Price|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|
# ...

# %%
df_pyspark = df_pyspark.drop('New Gross Product Price')

# %%
df_pyspark.show()
# Out:
# +---------+-----------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|
# +---------+-----------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# ...

# %%
df_pyspark.na.drop().show() #by default this is how='any'. but we can chage it to how='all'
# Out:
# +---------+-----------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|
# +---------+-----------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# ...

# %%
df_pyspark.na.drop(how='any', thresh=2).show() #threshold is for number of non null values in a row
# Out:
# +---------+-----------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|
# +---------+-----------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# ...

# %%
df_pyspark.na.drop(how='any',subset=['Tax Per Product']).show() #to drop the whole records if there are null values from the specificed column
# Out:
# +---------+-----------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|
# +---------+-----------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# ...

# %%
df_pyspark.na.fill('Missing Values').show()
# Out:
# +---------+-----------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|
# +---------+-----------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# ...

# %%
df_pyspark.na.fill('Missing Values',['Tax Per Product', ' OrderID ']).show()
# Out:
# +---------+-----------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|
# +---------+-----------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# ...

# %%
from pyspark.ml.feature import Imputer
imputer = Imputer(
    inputCols=['Tax Per Product'],
    outputCols=["{}_imputed".format(c) for c in ['Tax Per Product']]
    ).setStrategy("mean")#median, mode

# %%
imputer.fit(df_pyspark).transform(df_pyspark).show()
# Out:
# +---------+-----------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+-----------------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|Tax Per Product_imputed|
# ...

# %% [markdown]
# --------

# %%
df_pyspark.filter("`Tax Per Product`>7.0").show()
# Out:
# +---------+-------------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+--------------------+---------------+
# | OrderID |   Customer Name   |        Product Name| Product Description|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    |   Email            | Loyalty Points|
# +---------+-------------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+--------------------+---------------+
# ...

# %%
df_pyspark.filter(df_pyspark['Tax Per Product']>7.0).show() #another way to write
# Out:
# +---------+-------------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+--------------------+---------------+
# | OrderID |   Customer Name   |        Product Name| Product Description|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    |   Email            | Loyalty Points|
# +---------+-------------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+--------------------+---------------+
# ...

# %%
df_pyspark.filter("`Tax Per Product`>7.0").select([' Customer Name   ','Tax Per Product']).show()
# Out:
# +-------------------+---------------+
# |   Customer Name   |Tax Per Product|
# +-------------------+---------------+
# |   Jane Smith      |            8.4|
# |   Lucy Roberts    |           17.5|
# |   Mia Hughes      |           14.7|
# |   Lily Peterson   |           12.6|
# |   Owen Gray       |           21.0|
# |   Ethan Wilson    |           14.0|
# |   Lucas Taylor    |            7.7|
# |   Noah White      |            9.1|
# |   Mason Davis     |           18.9|
# |   Benjamin Clark  |           15.4|
# | Lucas Gonzalez    |          13.65|
# | Liam Torres       |           21.7|
# |   James White     |           14.7|
# |   Mason Brown     |            8.4|
# |   Harper Lewis    |           7.35|
# |   Jackson Clark   |           8.05|
# |   Wyatt Brooks    |           20.3|
# |   Benjamin Gomez  |          16.45|
# |   Zoe Mitchell    |            7.7|
# |   Eli Rodriguez   |          14.35|
# +-------------------+---------------+
# only showing top 20 rows

# %%
df_pyspark.filter((df_pyspark['Tax Per Product']>7.0) &
                  (df_pyspark['Product Category']=="Electronics")).show()
# Out:
# +---------+-----------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+--------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    |   Email            | Loyalty Points|
# +---------+-----------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+--------------------+---------------+
# ...

# %%
df_pyspark.filter((df_pyspark['Tax Per Product']>7.0) |
                  (df_pyspark['Product Category']=="Electronics")).show() #OR
# Out:
# +---------+-------------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+--------------------+---------------+
# | OrderID |   Customer Name   |        Product Name| Product Description|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    |   Email            | Loyalty Points|
# +---------+-------------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+--------------------+---------------+
# ...

# %%
df_pyspark.filter(~(df_pyspark['Tax Per Product']>7.0)).show()
# Out:
# +---------+-------------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+--------------------+---------------+
# | OrderID |   Customer Name   |        Product Name| Product Description|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    |   Email            | Loyalty Points|
# +---------+-------------------+--------------------+--------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+--------------------+---------------+
# ...

# %% [markdown]
# ---------

# %%
df_pyspark.groupBy(' Customer Name   ').sum().show()
# Out:
# +-------------------+--------------+--------------------+-----------------------+-------+-------+-------+------------+-------------+----------------+---------------+--------------------+
# |   Customer Name   |sum( OrderID )|sum(Tax Per Product)|sum(Quantity Purchased)|sum(GR)|sum(TT)|sum(NR)|sum( Rating)|sum( Stock  )|sum( Country ID)|sum( Phone    )|sum( Loyalty Points)|
# +-------------------+--------------+--------------------+-----------------------+-------+-------+-------+------------+-------------+----------------+---------------+--------------------+
# |   Emma Martinez   |          1049|                5.95|                      2|    170|   11.9|  158.1|         4.6|          275|               4|       19202122|                  20|
# |   Ava Scott       |          1078|                3.43|                      2|     98|   6.86|  91.14|         4.6|          230|               5|       92932002|                  28|
# ...

# %%
df_pyspark.groupBy('Product Category').mean().show()
# Out:
# +----------------+------------------+--------------------+-----------------------+------------------+------------------+------------------+------------------+-------------+------------------+--------------------+--------------------+
# |Product Category|    avg( OrderID )|avg(Tax Per Product)|avg(Quantity Purchased)|           avg(GR)|           avg(TT)|           avg(NR)|      avg( Rating)|avg( Stock  )|  avg( Country ID)|     avg( Phone    )|avg( Loyalty Points)|
# +----------------+------------------+--------------------+-----------------------+------------------+------------------+------------------+------------------+-------------+------------------+--------------------+--------------------+
# |        Security|            1062.0|                 4.9|                    3.0|             210.0|              14.7|             195.3|               4.9|        390.0|               4.0|         4.9505152E7|                 8.0|
# ...

# %%
df_pyspark.groupBy('Product Category').count().show()
# Out:
# +----------------+-----+
# |Product Category|count|
# +----------------+-----+
# |        Security|    1|
# |   Paint & Decor|    2|
# |         Outdoor|    2|
# |     Kitchenware|    2|
# |           Tools|    6|
# |     Electronics|    2|
# |       Gardening|    8|
# |        Lighting|    5|
# |       Furniture|    9|
# |        Plumbing|    4|
# |        Hardware|    2|
# | Home Essentials|    1|
# |      Home Decor|    8|
# |        Flooring|    2|
# +----------------+-----+

# %%
df_pyspark.agg({'Tax Per Product':'mean'}).show()
# Out:
# +--------------------+
# |avg(Tax Per Product)|
# +--------------------+
# |  7.8425925925925934|
# +--------------------+

# %%
df_pyspark.agg({' Loyalty Points':'sum'}).show()
# Out:
# +--------------------+
# |sum( Loyalty Points)|
# +--------------------+
# |                1230|
# +--------------------+

# %%
df_pyspark.groupBy('Product Category').max().show()
# Out:
# +----------------+--------------+--------------------+-----------------------+-------+-------+-------+------------+-------------+----------------+---------------+--------------------+
# |Product Category|max( OrderID )|max(Tax Per Product)|max(Quantity Purchased)|max(GR)|max(TT)|max(NR)|max( Rating)|max( Stock  )|max( Country ID)|max( Phone    )|max( Loyalty Points)|
# +----------------+--------------+--------------------+-----------------------+-------+-------+-------+------------+-------------+----------------+---------------+--------------------+
# |        Security|          1062|                 4.9|                      3|    210|   14.7|  195.3|         4.9|          390|               4|       49505152|                   8|
# |   Paint & Decor|          1033|                14.7|                      6|     50|   14.7|   35.3|         4.8|          500|               3|        7778888|                  12|
# ...

# %%
df_pyspark.groupBy('Product Category').min().show()
# Out:
# +----------------+--------------+--------------------+-----------------------+-------+-------+-------+------------+-------------+----------------+---------------+--------------------+
# |Product Category|min( OrderID )|min(Tax Per Product)|min(Quantity Purchased)|min(GR)|min(TT)|min(NR)|min( Rating)|min( Stock  )|min( Country ID)|min( Phone    )|min( Loyalty Points)|
# +----------------+--------------+--------------------+-----------------------+-------+-------+-------+------------+-------------+----------------+---------------+--------------------+
# |        Security|          1062|                 4.9|                      3|    210|   14.7|  195.3|         4.9|          390|               4|       49505152|                   8|
# |   Paint & Decor|          1030|                 1.4|                      1|     18|    8.4|    9.6|         4.7|          255|               1|        1497911|                   5|
# ...
