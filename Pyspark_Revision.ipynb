# %% [markdown]
# <a href="https://colab.research.google.com/github/sathvik3103/Pyspark/blob/main/Pyspark_Revision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip -q install pyspark

# %%
import pyspark

# %%
import pandas as pd
pd.read_csv("/content/Tailwind Traders Sales.csv")
# Out:
#      OrderID      Customer Name                Product Name  \
# 0        1024     Jane Smith               UltraGrip Hammer
# 1        1025     Darren White            Luminous Bulb 60W
# 2        1026     Lucy Roberts                Oakwood Shelf
# 3        1027     Mark Lewis                 ProTile Cutter
# 4        1028     Olivia Graham            Garden Glove Set
# 5        1029     Jack Thompson         Steel Nails (1inch)
# 6        1030     Mia Hughes            Luxury Paint (Blue)
# 7        1031     Aaron Walker         Kitchen Sink (Steel)
# 8        1032     Lily Peterson             Power Drill Set
# 9        1033     Ben Foster               Floral Wallpaper
# 10       1034     Owen Gray                 Brass Door Knob
# 11       1035     Amelia Carter           LED Garden Lights
# 12       1036     Liam Clark                    Compost Bin
# 13       1037     Sophia Turner          Ceramic Vase (Red)
# 14       1038     Jacob Moore               Patio Chair Set
# ...

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Practice").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://e2976fe86fe9:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
dff = spark.read.csv("/content/Tailwind Traders Sales.csv")

# %%
dff
# Out:
# DataFrame[_c0: string, _c1: string, _c2: string, _c3: string, _c4: string, _c5: string, _c6: string, _c7: string, _c8: string, _c9: string, _c10: string, _c11: string, _c12: string, _c13: string, _c14: string, _c15: string, _c16: string, _c17: string, _c18: string, _c19: string, _c20: string, _c21: string, _c22: string, _c23: string, _c24: string]

# %%
dff.show()
# Out:
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+-------------------+---------+----------+------------------+---------------+
# |      _c0|              _c1|                 _c2|                 _c3|                _c4|            _c5|               _c6|_c7|  _c8|   _c9|            _c10|        _c11|    _c12|    _c13|    _c14|   _c15|    _c16|       _c17|       _c18|       _c19|               _c20|     _c21|      _c22|              _c23|           _c24|
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+-------------------+---------+----------+------------------+---------------+
# ...

# %%
spark.read.option("header","true").csv("/content/Tailwind Traders Sales.csv").show()
# Out:
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Gross Product Price|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# ...

# %%
type(dff)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
dff.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#  |-- _c8: string (nullable = true)
#  |-- _c9: string (nullable = true)
#  |-- _c10: string (nullable = true)
#  |-- _c11: string (nullable = true)
#  |-- _c12: string (nullable = true)
#  |-- _c13: string (nullable = true)
#  |-- _c14: string (nullable = true)
#  |-- _c15: string (nullable = true)
#  |-- _c16: string (nullable = true)
#  |-- _c17: string (nullable = true)
#  |-- _c18: string (nullable = true)
#  |-- _c19: string (nullable = true)
#  |-- _c20: string (nullable = true)
#  |-- _c21: string (nullable = true)
#  |-- _c22: string (nullable = true)
#  |-- _c23: string (nullable = true)
#  |-- _c24: string (nullable = true)

# %% [markdown]
# because default is string

# %%
dff = spark.read.csv("/content/Tailwind Traders Sales.csv",header=True,inferSchema=True)

# %%
dff.show()
# Out:
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Gross Product Price|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# ...

# %%
dff.printSchema()
# Out:
# root
#  |--  OrderID : integer (nullable = true)
#  |--  Customer Name   : string (nullable = true)
#  |-- Product Name: string (nullable = true)
#  |-- Product Description: string (nullable = true)
#  |-- Gross Product Price: integer (nullable = true)
#  |-- Tax Per Product: double (nullable = true)
#  |-- Quantity Purchased: integer (nullable = true)
#  |-- GR: integer (nullable = true)
#  |-- TT: double (nullable = true)
#  |-- NR: double (nullable = true)
#  |-- Product Category: string (nullable = true)
#  |--  SKU Number : string (nullable = true)
#  |--  Weight : string (nullable = true)
#  |--  Color  : string (nullable = true)
#  |--  Size  : string (nullable = true)
#  |--  Rating: double (nullable = true)
#  |--  Stock  : integer (nullable = true)
#  |--  Country ID: integer (nullable = true)
#  |--  Sales Rep : string (nullable = true)
#  |--  CustomerID: string (nullable = true)
#  |--  Address        : string (nullable = true)
#  |--  Zip Code: string (nullable = true)
# ...

# %%
dff.select('Product Name')
# Out:
# DataFrame[Product Name: string]

# %%
dff.select('Product Name').show()
# Out:
# +--------------------+
# |        Product Name|
# +--------------------+
# |    UltraGrip Hammer|
# |   Luminous Bulb 60W|
# |       Oakwood Shelf|
# |      ProTile Cutter|
# |    Garden Glove Set|
# | Steel Nails (1inch)|
# | Luxury Paint (Blue)|
# |Kitchen Sink (Steel)|
# |     Power Drill Set|
# |    Floral Wallpaper|
# |     Brass Door Knob|
# |   LED Garden Lights|
# |         Compost Bin|
# |  Ceramic Vase (Red)|
# |     Patio Chair Set|
# |  Electric Lawnmower|
# |      Kitchen Faucet|
# | Designer Wall Clock|
# |  Granite Countertop|
# |       Teakwood Desk|
# +--------------------+
# only showing top 20 rows

# %%
dff.dtypes
# Out:
# [(' OrderID ', 'int'),
#  (' Customer Name   ', 'string'),
#  ('Product Name', 'string'),
#  ('Product Description', 'string'),
#  ('Gross Product Price', 'int'),
#  ('Tax Per Product', 'double'),
#  ('Quantity Purchased', 'int'),
#  ('GR', 'int'),
#  ('TT', 'double'),
#  ('NR', 'double'),
#  ('Product Category', 'string'),
#  (' SKU Number ', 'string'),
#  (' Weight ', 'string'),
#  (' Color  ', 'string'),
#  (' Size  ', 'string'),
#  (' Rating', 'double'),
#  (' Stock  ', 'int'),
#  (' Country ID', 'int'),
#  (' Sales Rep ', 'string'),
#  (' CustomerID', 'string'),
#  (' Address        ', 'string'),
#  (' Zip Code', 'string'),
#  (' Phone    ', 'int'),
#  (' Email            ', 'string'),
#  (' Loyalty Points', 'int')]

# %%
dff.describe().show()
# Out:
# +-------+-----------------+-----------------+--------------------+--------------------+-------------------+------------------+------------------+------------------+-----------------+-----------------+----------------+------------+-----------------+--------+--------+------------------+-----------------+------------------+-----------+-----------+-----------------+-----------------+-------------------+--------------------+------------------+
# |summary|         OrderID | Customer Name   |        Product Name| Product Description|Gross Product Price|   Tax Per Product|Quantity Purchased|                GR|               TT|               NR|Product Category| SKU Number |          Weight | Color  |  Size  |            Rating|          Stock  |        Country ID| Sales Rep | CustomerID|  Address        |         Zip Code|          Phone    |   Email            |    Loyalty Points|
# ...

# %%
dff = dff.withColumn('   Tax Per Product',dff['Tax Per Product']+20)

# %%
dff.show()
# Out:
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+------------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Gross Product Price|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|   Tax Per Product|
# ...

# %%
dff = dff.withColumnRenamed('   Tax Per Product','New Tax Per Product')

# %%
dff.show()
# Out:
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+-------------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Gross Product Price|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|New Tax Per Product|
# ...

# %%
dff = dff.drop('New Tax Per Product')
dff.show()
# Out:
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# | OrderID | Customer Name   |        Product Name| Product Description|Gross Product Price|Tax Per Product|Quantity Purchased| GR|   TT|    NR|Product Category| SKU Number | Weight | Color  |  Size  | Rating| Stock  | Country ID| Sales Rep | CustomerID|     Address        | Zip Code| Phone    | Email            | Loyalty Points|
# +---------+-----------------+--------------------+--------------------+-------------------+---------------+------------------+---+-----+------+----------------+------------+--------+--------+--------+-------+--------+-----------+-----------+-----------+--------------------+---------+----------+------------------+---------------+
# ...
